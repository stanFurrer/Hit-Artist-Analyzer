# %%
import pandas as pd
from ast import literal_eval

# %%
artists = ['Frank Sinatra', 'The Beatles', 'Michael Jackson', 'Eminem', 'Rihanna']

# %%
import re
import unidecode

def remove_superflous(text):
    text = re.sub(r'\([^)]*\)', '', text).split('-')[0]
    text = unidecode.unidecode(text)
    text = text.lower().replace("'", "").replace("’", "")\
                        .replace("‘","").replace('/', '')\
                        .replace("\"", "").replace(".","")\
                        .replace("?", "").replace("!", "")\
                        .replace("&", "and").replace(':','')\
                        .replace(",", "").replace('  ', ' ')
    while text[0] == ' ':
        text = text[1:]
    while text[-1] == ' ':
        text = text[:-1]

    text = re.sub(r'\d+$', '', text)
    
    return text.replace(' ', '_')
                             
#Load all lyrics
lyrics = pd.read_csv('../data/full_lyrics_df.csv').drop('Unnamed: 0', axis=1)

#Load all relevant musics
music = pd.read_csv('../data/full_spotify_df.csv').drop('Unnamed: 0', axis=1)
music.artists_album = music.artists_album.map(lambda artists: literal_eval(artists)[0]['name'])
music = music[music.artists_album.isin(artists)]

music['clean_title'] = music.name_track.map(lambda track: remove_superflous(track))
lyrics['clean_title'] = lyrics.title.map(lambda title: remove_superflous(title) if title != '313' and title != '1999' else title)
#MJ track Shoo-Be-Doo-Be-Doo-Da-Day gets changed for shoo in the clean title category; not a problem as there are no other Shoo songs

music = music[~(music.clean_title.map(lambda title: title.lower()).str.contains('mix'))]
music = music[~(music.name_album == 'XSCAPE - Track by Track Commentary')]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('mix'))]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('monologue'))]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('segment'))]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('announcement'))]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('presentation'))]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('medley'))]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('remarks'))]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('introduction'))]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('speak'))]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('welcome'))]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('skit'))]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('interview'))]
music = music[~(music.name_track.map(lambda track: track.lower()).str.contains('excerpt'))]
music = music[~(music.name_album == "Selections From A Voice On Air (1935-1955)")]

music.loc[(music.clean_title.map(lambda title: title) == 'i_get_along_with_you_very_well'), 'clean_title'] = 'i_get_along_without_you_very_well'
music.loc[(music.clean_title.map(lambda title: title) == 'lady_is_a_tramp'), 'clean_title'] = 'the_lady_is_a_tramp'
music.loc[(music.clean_title.map(lambda title: title) == 'play_on_clarke_street'), 'clean_title'] = 'clarke_street'
music.loc[(music.clean_title.map(lambda title: title) == 'play_off_the_tender_trap'), 'clean_title'] = 'the_tender_trap'
music.loc[(music.clean_title.map(lambda title: title) == 'bows_the_tender_trap'), 'clean_title'] = 'the_tender_trap'
music.loc[(music.clean_title.map(lambda title: title) == 'how_do_you_keep_the_music_playing_'), 'clean_title'] = 'how_do_you_keep_the_music_playing'

music.loc[(music.name_track.map(lambda track: track.lower()).str.contains('\*')), 'clean_title'] = 'asshole'


lyrics = lyrics[~(lyrics.clean_title.map(lambda title: title.lower()).str.contains('mix'))]
lyrics = lyrics.append(lyrics[(lyrics.clean_title == 'it_came_upon_the_midnight_clear')])
lyrics.loc[lyrics.clean_title == 'it_came_upon_the_midnight_clear', 'clean_title'] = ['it_came_upon_the_midnight_clear', 'it_came_upon_a_midnight_clear']
lyrics = lyrics.append(lyrics[(lyrics.clean_title == 'day_in')])
lyrics.loc[lyrics.clean_title == 'day_in', 'clean_title'] = ['day_in', 'day_in_day_out']
lyrics = lyrics.append(lyrics[(lyrics.clean_title == 'you_brought_a_new_kind_of_love_to_me')])
lyrics.loc[lyrics.clean_title == 'you_brought_a_new_kind_of_love_to_me', 'clean_title'] = ['you_brought_a_new_kind_of_love_to_me', 'you_brought_a_new_kind_of_love']
lyrics = lyrics.append(lyrics[(lyrics.clean_title == 'hey_look_no_crying')])
lyrics.loc[lyrics.clean_title == 'hey_look_no_crying', 'clean_title'] = ['hey_look_no_crying', 'hey_look_no_cryin']
lyrics.loc[lyrics.clean_title == 'one_hundred_years_from_today', 'clean_title'] = ['a_hundred_years_from_today']
lyrics.loc[lyrics.clean_title == 'song_is_you', 'clean_title'] = ['the_song_is_you']
lyrics.loc[lyrics.clean_title == 'when_im_sixty', 'clean_title'] = ['when_im_sixty_four', 'when_im_sixty', 'when_im_sixty']

# %%
lyrics.columns
# Out:
# Index(['artist_id', 'artist_name', 'featured_artists', 'featured_video',
#        'full_title', 'header_image_thumbnail_url', 'header_image_url',
#        'lyrics', 'lyrics_state', 'release_date', 'release_date_for_display',
#        'song_art_image_thumbnail_url', 'song_art_image_url', 'title',
#        'title_with_featured', 'clean_title'],
#       dtype='object')

# %%
lyrics[lyrics.clean_title.str.contains('april')]
# Out:
#       artist_id    artist_name featured_artists  featured_video  \
# 1700        824  Frank Sinatra               []           False
# 2042        824  Frank Sinatra               []           False
# 2183        824  Frank Sinatra               []           False
#
#                                     full_title  \
# 1700           April in Paris by Frank Sinatra
# 2042      I'll Remember April by Frank Sinatra
# 2183  April Played The Fiddle by Frank Sinatra
#
#                              header_image_thumbnail_url  \
# 1700  https://images.rapgenius.com/d7973fb995bcb7b71...
# 2042  https://images.genius.com/f0a3e4b4f57b855953a3...
# 2183  https://images.genius.com/5f746dbf6c41747811e1...
#
#                                        header_image_url  \
# 1700  https://images.rapgenius.com/d7973fb995bcb7b71...
# 2042  https://images.genius.com/f0a3e4b4f57b855953a3...
# 2183  https://images.genius.com/5f746dbf6c41747811e1...
#
#                                                  lyrics lyrics_state  \
# 1700                                                NaN     complete
# 2042  This lovely day will lengthen into evening, we...     complete
# 2183  April played a fiddle\nAnd my heart began to d...     complete
#
#      release_date release_date_for_display  \
# 1700   1958-01-06          January 6, 1958
# 2042          NaN                      NaN
# 2183          NaN                      NaN
#
#                            song_art_image_thumbnail_url  \
# 1700  https://images.rapgenius.com/d7973fb995bcb7b71...
# 2042  https://images.genius.com/f0a3e4b4f57b855953a3...
# 2183  https://images.genius.com/5f746dbf6c41747811e1...
#
#                                      song_art_image_url  \
# 1700  https://images.rapgenius.com/d7973fb995bcb7b71...
# 2042  https://images.genius.com/f0a3e4b4f57b855953a3...
# 2183  https://images.genius.com/5f746dbf6c41747811e1...
#
#                         title      title_with_featured  \
# 1700           April in Paris           April in Paris
# 2042      I’ll Remember April      I'll Remember April
# 2183  April Played The Fiddle  April Played The Fiddle
#
#                   clean_title
# 1700           april_in_paris
# 2042       ill_remember_april
# 2183  april_played_the_fiddle

# %%
missing_titles = set(music.clean_title.unique()) - (set(music.clean_title.unique()) & (set(lyrics.clean_title.unique())))
len(missing_titles)
# Out:
# 40

# %%
lyrics[~lyrics.lyrics.isnull()]
# Out:
#       artist_id      artist_name featured_artists  featured_video  \
# 0           835  Michael Jackson               []            True
# 1           835  Michael Jackson               []           False
# 2           835  Michael Jackson               []            True
# 3           835  Michael Jackson               []            True
# 4           835  Michael Jackson               []           False
# ...         ...              ...              ...             ...
# 3186        586      The Beatles               []           False
# 1543        824    Frank Sinatra               []           False
# 1588        824    Frank Sinatra               []           False
# 1519        824    Frank Sinatra               []           False
# 1826        824    Frank Sinatra               []           False
#
#                                              full_title  \
# 0                        Billie Jean by Michael Jackson
# 1                    Smooth Criminal by Michael Jackson
# 2           They Don't Care About Us by Michael Jackson
# 3                  Man in the Mirror by Michael Jackson
# 4        Wanna Be Startin' Somethin' by Michael Jackson
# ...                                                 ...
# 3186  Slow Down [Live at the BBC Disk 2] by The Beatles
# 1543   It Came Upon The Midnight Clear by Frank Sinatra
# 1588                    Day In-Day Out by Frank Sinatra
# 1519  You Brought A New Kind Of Love To Me by Frank ...
# 1826               Hey Look, No Crying by Frank Sinatra
#
#                              header_image_thumbnail_url  \
# 0     https://images.genius.com/9ed845cfd193f95cf6bd...
# 1     https://images.genius.com/b9bfb36a041733c7bbf6...
# 2     https://images.genius.com/ed7f9a530d1417005450...
# 3     https://images.genius.com/b9bfb36a041733c7bbf6...
# 4     https://images.genius.com/9ed845cfd193f95cf6bd...
# ...                                                 ...
# 3186  https://images.genius.com/ee65356f34b721b742f8...
# 1543  https://images.genius.com/14f490fb556eb4749a3c...
# 1588  https://images.genius.com/64ea8bfac9c50b142c9e...
# 1519  https://images.genius.com/0a6f3a767513140a0712...
# 1826  https://images.genius.com/2c8ab9e91adc8a263464...
#
#                                        header_image_url  \
# 0     https://images.genius.com/9ed845cfd193f95cf6bd...
# 1     https://images.genius.com/b9bfb36a041733c7bbf6...
# 2     https://images.genius.com/ed7f9a530d1417005450...
# 3     https://images.genius.com/b9bfb36a041733c7bbf6...
# 4     https://images.genius.com/9ed845cfd193f95cf6bd...
# ...                                                 ...
# 3186  https://images.genius.com/ee65356f34b721b742f8...
# 1543  https://images.genius.com/14f490fb556eb4749a3c...
# 1588  https://images.genius.com/64ea8bfac9c50b142c9e...
# 1519  https://images.genius.com/0a6f3a767513140a0712...
# 1826  https://images.genius.com/2c8ab9e91adc8a263464...
#
#                                                  lyrics lyrics_state  \
# 0     She was more like a beauty queen from a movie ...     complete
# 1     As he came into the window\nWas a sound of a c...     complete
# 2     All I want to say is that they don’t really ca...     complete
# 3     I'm gonna make a change\nFor once in my life\n...     complete
# 4     I said you want to be starting something\nYou ...     complete
# ...                                                 ...          ...
# 3186  {Intro}\nWell, come on pretty baby, won't you ...     complete
# 1543  It came upon the midnight clear, that glorious...     complete
# 1588  Day in-day out\nThe same old voodoo follows me...     complete
# 1519  If the nightingales could sing like you\nThey'...     complete
# 1826  Hey, look, no crying, though she has one foot ...     complete
#
#      release_date release_date_for_display  \
# 0      1982-11-30        November 30, 1982
# 1      1988-10-21         October 21, 1988
# 2      1995-06-16            June 16, 1995
# 3      1988-01-16         January 16, 1988
# 4      1982-11-30        November 30, 1982
# ...           ...                      ...
# 3186   1994-11-30        November 30, 1994
# 1543          NaN                     1948
# 1588   1959-01-05          January 5, 1959
# 1519   1956-01-01          January 1, 1956
# 1826          NaN                      NaN
#
#                            song_art_image_thumbnail_url  \
# 0     https://images.genius.com/6d6f4e98e26c6a3b8851...
# 1     https://images.genius.com/855c88af95861ef86647...
# 2     https://images.genius.com/ed7f9a530d1417005450...
# 3     https://images.genius.com/5f300a134f36d755a3a7...
# 4     https://images.genius.com/4ac74a8139e1a549cf94...
# ...                                                 ...
# 3186  https://images.genius.com/ee65356f34b721b742f8...
# 1543  https://images.genius.com/14f490fb556eb4749a3c...
# 1588  https://images.genius.com/64ea8bfac9c50b142c9e...
# 1519  https://images.genius.com/0a6f3a767513140a0712...
# 1826  https://images.genius.com/2c8ab9e91adc8a263464...
#
#                                      song_art_image_url  \
# 0     https://images.genius.com/6d6f4e98e26c6a3b8851...
# 1     https://images.genius.com/855c88af95861ef86647...
# 2     https://images.genius.com/ed7f9a530d1417005450...
# 3     https://images.genius.com/5f300a134f36d755a3a7...
# 4     https://images.genius.com/4ac74a8139e1a549cf94...
# ...                                                 ...
# 3186  https://images.genius.com/ee65356f34b721b742f8...
# 1543  https://images.genius.com/14f490fb556eb4749a3c...
# 1588  https://images.genius.com/64ea8bfac9c50b142c9e...
# 1519  https://images.genius.com/0a6f3a767513140a0712...
# 1826  https://images.genius.com/2c8ab9e91adc8a263464...
#
#                                      title  \
# 0                              Billie Jean
# 1                          Smooth Criminal
# 2                 They Don’t Care About Us
# 3                        Man in the Mirror
# 4              Wanna Be Startin’ Somethin’
# ...                                    ...
# 3186    Slow Down [Live at the BBC Disk 2]
# 1543       It Came Upon The Midnight Clear
# 1588                        Day In-Day Out
# 1519  You Brought A New Kind Of Love To Me
# 1826                   Hey Look, No Crying
#
#                        title_with_featured                         clean_title
# 0                              Billie Jean                         billie_jean
# 1                          Smooth Criminal                     smooth_criminal
# 2                 They Don't Care About Us             they_dont_care_about_us
# 3                        Man in the Mirror                   man_in_the_mirror
# 4              Wanna Be Startin' Somethin'           wanna_be_startin_somethin
# ...                                    ...                                 ...
# 3186    Slow Down [Live at the BBC Disk 2]  slow_down_[live_at_the_bbc_disk_2]
# 1543       It Came Upon The Midnight Clear       it_came_upon_a_midnight_clear
# 1588                        Day In-Day Out                      day_in_day_out
# 1519  You Brought A New Kind Of Love To Me      you_brought_a_new_kind_of_love
# 1826                   Hey Look, No Crying                   hey_look_no_cryin
#
# [3039 rows x 16 columns]

# %%
missing_lyrics = set(music.clean_title.unique()) - (set(music.clean_title.unique()) & (set(lyrics[~lyrics.lyrics.isnull()].clean_title.unique())))
missing_lyrics
# Out:
# {'a_long_night',
#  'a_real_treat',
#  'absolutely_fab',
#  'and_here_we_are_again',
#  'april_in_paris',
#  'bad_guy',
#  'bows_my_way',
#  'bows_you_are_there',
#  'brian_bathtubes',
#  'bumper_bundle',
#  'bye_bye',
#  'clarke_street',
#  'concierto_de_aranjuez',
#  'dont_cry_joe',
#  'drive_my_car',
#  'flying',
#  'george',
#  'golden_slumbers_carry_that_weight',
#  'happy_birthday_dear_saturday_club',
#  'hey_paul',
#  'hush',
#  'i_concentrate_on_you',
#  'if_i_wasnt_in_america',
#  'im_talking_about_you',
#  'john',
#  'leave_it_all_to_me',
#  'lift_lid_again',
#  'lower_5e',
#  'march_of_the_meanies',
#  'never_mind_eh',
#  'new_york_bows',
#  'nice_guy',
#  'ninna_nanna',
#  'now_hush_hush',
#  'on_fire',
#  'pepperland',
#  'pepperland_laid_waste',
#  'ringo_yep',
#  'sea_of_holes',
#  'sea_of_monsters',
#  'sea_of_time',
#  'so_much_better',
#  'somebodys_watching_me',
#  'taking_a_chance_on_love',
#  'thats_all_right',
#  'the_49_weeks',
#  'the_future_song_without_words',
#  'the_hippy_hippy_shake',
#  'the_shadow_of_your_smile',
#  'this_cant_be_love',
#  'torture',
#  'what_is_it_george',
#  'when_joanna_loved_me',
#  'yellow_submarine_in_pepperland'}

# %% [markdown]
# There are 110 songs in the music DF that find no match in the lyrics df.

# %% [markdown]
# ### Merge

# %%
lyrics = lyrics[~lyrics.lyrics.isnull()].drop_duplicates(subset='clean_title')[['clean_title', 'lyrics', 'lyrics_state']]

# %%
full_df = music.merge(lyrics, how='left', on='clean_title').drop('Unnamed: 0.1', axis=1)

# %% [markdown]
# ### Missing lyrics:
#
# - Leave it all to me - Sinatra
# - Hush-A-Bye Island - Sinatra
# - This Can't Be Love - Sinatra
# - Watching Me - MJ
# - Torture - MJ
# - Nice Guy - Eminem
# - When Joanna Loved Me - Sinatra
#
# ### To add
# - Something - Beatles
# - Oh Darling - Beatles
# - Good Night - Beatles
# - Drive My Car - Beatles
# - Taking a Chance on Love - Sinatra
# - Something - WRITTEN BY THE BEATLES AND SANG BY SINATRA ==> Same lyrics
# - Shadow of Your Smile - Sinatra
# - April In Paris - Sinatra
# - I Concentrate On You - Sinatra
# - Don't Cry Joe - Sinatra
# - A long Night - Sinatra
# - The Future - Sinatra
# - Bad Guy - Eminem
# - So Much Better - Eminem
# - On Fire - Eminem
# - Rap God - Eminem
# -
# ### Others
# - Yellow Submarine: instrumentals
# - Live At The BBC (1 and 2): interviews
# - Trilogy: Past, Present...; live at meadowlands; Concierto;   : instrumental

# %%
#is_it_scary_lyrics = open('../processbook/missing_lyrics/is_it_scary.txt', 'r').read()
watching_me_lyrics = open('missing_lyrics/watching_me.txt', 'r').read()
torture_lyrics = open('missing_lyrics/torture.txt', 'r').read()
leave_it_all_lyrics = open('missing_lyrics/leave_it_all.txt', 'r').read()
hush_a_bye_lyrics = open('missing_lyrics/hush_a_bye.txt', 'r').read()
this_cant_be_love_lyrics = open('missing_lyrics/this_cant_be_love.txt', 'r').read()
nice_guy_lyrics = open('missing_lyrics/nice_guy.txt', 'r').read()
joanna_love_lyrics = open('missing_lyrics/joanna_love.txt', 'r').read()
you_da_one_lyrics = open('missing_lyrics/you_da_one.txt', 'r').read()

something_lyrics = open('missing_lyrics/something.txt', 'r').read()
oh_darling_lyrics = open('missing_lyrics/oh_darling.txt', 'r').read()
good_night_lyrics = open('missing_lyrics/good_night.txt', 'r').read()
drive_my_car_lyrics = open('missing_lyrics/drive_my_car.txt', 'r').read()
taking_a_chance_on_love_lyrics = open('missing_lyrics/taking_a_chance_on_love.txt', 'r').read()
shadow_of_your_smile_lyrics = open('missing_lyrics/shadow_of_your_smile.txt', 'r').read()
april_in_paris_lyrics = open('missing_lyrics/april_in_paris.txt', 'r').read()
concentrate_on_you_lyrics = open('missing_lyrics/concentrate_on_you.txt', 'r').read()
dont_cry_joe_lyrics = open('missing_lyrics/dont_cry_joe.txt', 'r').read()
long_night_lyrics = open('missing_lyrics/long_night.txt', 'r').read()
the_future_lyrics = open('missing_lyrics/the_future.txt', 'r').read()
bad_guy_lyrics = open('missing_lyrics/bad_guy.txt', 'r').read()
so_much_better_lyrics = open('missing_lyrics/so_much_better.txt', 'r').read()
on_fire_lyrics = open('missing_lyrics/on_fire.txt', 'r').read()
rap_god_lyrics = open('missing_lyrics/rap_god.txt', 'r').read()

# %%
full_df.loc[full_df.clean_title.str.contains('watching_me'), 'lyrics'] = watching_me_lyrics
full_df.loc[full_df.clean_title.str.contains('torture'), 'lyrics'] = torture_lyrics
full_df.loc[full_df.clean_title.str.contains('leave_it_all'), 'lyrics'] = leave_it_all_lyrics
full_df.loc[full_df.clean_title == 'hush', 'lyrics'] = hush_a_bye_lyrics
full_df.loc[full_df.clean_title == 'nice_guy', 'lyrics'] = nice_guy_lyrics
full_df.loc[full_df.clean_title.str.contains('joanna'), 'lyrics'] = joanna_love_lyrics
full_df.loc[full_df.clean_title.str.contains('this_cant'), 'lyrics'] = this_cant_be_love_lyrics
full_df.loc[full_df.clean_title.str.contains('you_da_one'), 'lyrics'] = you_da_one_lyrics
full_df.loc[full_df.clean_title.str.contains('something'), 'lyrics'] = something_lyrics
full_df.loc[full_df.clean_title.str.contains('oh_darling'), 'lyrics'] = oh_darling_lyrics
full_df.loc[full_df.clean_title.str.contains('good_night'), 'lyrics'] = good_night_lyrics
full_df.loc[full_df.clean_title.str.contains('drive_my_car'), 'lyrics'] = drive_my_car_lyrics
full_df.loc[full_df.clean_title.str.contains('taking_a_chance_on_love'), 'lyrics'] = taking_a_chance_on_love_lyrics
full_df.loc[full_df.clean_title.str.contains('shadow_of_your_smile'), 'lyrics'] = shadow_of_your_smile_lyrics
full_df.loc[full_df.clean_title.str.contains('april_in_paris'), 'lyrics'] = april_in_paris_lyrics
full_df.loc[full_df.clean_title.str.contains('concentrate_on_you'), 'lyrics'] = concentrate_on_you_lyrics
full_df.loc[full_df.clean_title.str.contains('cry_joe'), 'lyrics'] = dont_cry_joe_lyrics
full_df.loc[full_df.clean_title.str.contains('long_night'), 'lyrics'] = long_night_lyrics
full_df.loc[full_df.clean_title.str.contains('the_future_song'), 'lyrics'] = the_future_lyrics
full_df.loc[full_df.clean_title.str.contains('bad_guy'), 'lyrics'] = bad_guy_lyrics
full_df.loc[full_df.clean_title.str.contains('so_much_better'), 'lyrics'] = so_much_better_lyrics
full_df.loc[full_df.clean_title.str.contains('on_fire'), 'lyrics'] = on_fire_lyrics
full_df.loc[full_df.clean_title.str.contains('rap_god'), 'lyrics'] = rap_god_lyrics
full_df.loc[full_df.lyrics.isnull(), 'lyrics'] = "<Instrumental>"

# %%
full_df
# Out:
#                       name_track  duration_ms  explicit      artists_track  \
# 0     Nice 'N' Easy - Remastered       165786     False  ['Frank Sinatra']
# 1                  Ol' Macdonald       160306     False  ['Frank Sinatra']
# 2               Sentimental Baby       156280     False  ['Frank Sinatra']
# 3      Love Looks So Well On You       158893     False  ['Frank Sinatra']
# 4                     Sleep Warm       166066     False  ['Frank Sinatra']
# ...                          ...          ...       ...                ...
# 1707              Watch n' Learn       211000     False        ['Rihanna']
# 1708                    Farewell       256506     False        ['Rihanna']
# 1709                Red Lipstick       217440      True        ['Rihanna']
# 1710                 Do Ya Thang       223413      True        ['Rihanna']
# 1711                Fool In Love       255853     False        ['Rihanna']
#
#                               artists_track_uri  featuring  track_number  \
# 0     ['spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0']      False             1
# 1     ['spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0']      False             2
# 2     ['spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0']      False             3
# 3     ['spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0']      False             4
# 4     ['spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0']      False             5
# ...                                         ...        ...           ...
# 1707  ['spotify:artist:5pKCCKE2ajJHZ9KAiaK11H']      False            10
# 1708  ['spotify:artist:5pKCCKE2ajJHZ9KAiaK11H']      False            11
# 1709  ['spotify:artist:5pKCCKE2ajJHZ9KAiaK11H']      False            12
# 1710  ['spotify:artist:5pKCCKE2ajJHZ9KAiaK11H']      False            13
# 1711  ['spotify:artist:5pKCCKE2ajJHZ9KAiaK11H']      False            14
#
#       disc_number                            name_album  artists_album  ...  \
# 0               1  Sinatra Sings Alan & Marilyn Bergman  Frank Sinatra  ...
# 1               1  Sinatra Sings Alan & Marilyn Bergman  Frank Sinatra  ...
# 2               1  Sinatra Sings Alan & Marilyn Bergman  Frank Sinatra  ...
# 3               1  Sinatra Sings Alan & Marilyn Bergman  Frank Sinatra  ...
# 4               1  Sinatra Sings Alan & Marilyn Bergman  Frank Sinatra  ...
# ...           ...                                   ...            ...  ...
# 1707            1      Talk That Talk (Deluxe Explicit)        Rihanna  ...
# 1708            1      Talk That Talk (Deluxe Explicit)        Rihanna  ...
# 1709            1      Talk That Talk (Deluxe Explicit)        Rihanna  ...
# 1710            1      Talk That Talk (Deluxe Explicit)        Rihanna  ...
# 1711            1      Talk That Talk (Deluxe Explicit)        Rihanna  ...
#
#       speechiness acousticness instrumentalness  liveness  valence    tempo  \
# 0          0.0327     0.876000         0.000000     0.111   0.4710  109.937
# 1          0.0375     0.738000         0.000000     0.181   0.7300   84.750
# 2          0.0294     0.899000         0.000501     0.169   0.2850   82.298
# 3          0.0317     0.901000         0.000457     0.107   0.2010   85.471
# 4          0.0320     0.929000         0.014200     0.110   0.1390   88.004
# ...           ...          ...              ...       ...      ...      ...
# 1707       0.1220     0.003040         0.000134     0.282   0.8230  168.010
# 1708       0.1110     0.080500         0.000000     0.153   0.5060   80.004
# 1709       0.1180     0.064900         0.000000     0.649   0.3090  139.950
# 1710       0.0369     0.000924         0.000014     0.101   0.6970  174.085
# 1711       0.0473     0.045000         0.000004     0.310   0.0433  111.835
#
#       time_signature                clean_title  \
# 0                  4                nice_n_easy
# 1                  4               ol_macdonald
# 2                  3           sentimental_baby
# 3                  4  love_looks_so_well_on_you
# 4                  5                 sleep_warm
# ...              ...                        ...
# 1707               4              watch_n_learn
# 1708               4                   farewell
# 1709               4               red_lipstick
# 1710               4                do_ya_thang
# 1711               4               fool_in_love
#
#                                                  lyrics  lyrics_state
# 0     Let's take it nice and easy\nIt's gonna be so ...      complete
# 1     Ol' MacDonald had a farm, E-I-E-I-O\nAnd on th...      complete
# 2     Sentimental baby, sweet and gentle baby\nJust ...      complete
# 3     Like moonlight looks on a country side, like a...      complete
# 4     Sleep warm, sleep tight, when you turn off the...      complete
# ...                                                 ...           ...
# 1707  Won’t say a thing\nAbout the way you love me\n...      complete
# 1708  Ricky Racks\nFor what it's worth\nYou were a s...      complete
# 1709  Red lipstick, all on the paper\nLemme take a h...      complete
# 1710  Know I'm missin' that kissin' in the rover\nBo...      complete
# 1711  Mama, I found a man\nWho loves me and understa...      complete
#
# [1712 rows x 28 columns]

# %%
missing_lyrics = full_df[(full_df.drop('lyrics_state', axis=1).isnull().any(axis=1))][['clean_title', 'name_track', 'name_album', 'artists_album']]

# %%
full_df.to_csv('../data/spot_lyr_df.csv')

# %%
missing_lyrics.to_csv('../data/missing_lyrics.csv')

# %%
missing_lyrics.count()
# Out:
# clean_title      0
# name_track       0
# name_album       0
# artists_album    0
# dtype: int64

# %% [markdown]
# # Find missing lyrics

# %%
missing_lyrics_df = missing_lyrics.copy()

missing_lyrics_df.reset_index(drop=True, inplace=True)

missing_lyrics_df['clean_title'] = missing_lyrics_df['clean_title'].str.replace("_", " ")

# for some reasons, the 'artists_track' column is now a "string":: "['Frank Sinatra']". Convert it back to list.

import ast
missing_lyrics_df['artists_track'] = missing_lyrics_df['artists_track'].apply(ast.literal_eval)

missing_lyrics_df.head(2)

import lyricsgenius

genius = lyricsgenius.Genius(
    "5y-Ynf87UKhSvEAB90B3eAT3P6Y-aiVft2qPYMVtyRVi85u4JhgOQQrXaJiTyJN0"
)

def get_lyrics(title, artist, genius=genius):
    song = genius.search_song(title, artist)
    
    if song:
        return song.lyrics
    else:
        return ""

# Get missing lyrics

def get_missing_lyrics(missing_lyrics_df):
    missing_lyrics_df['lyrics'] = ""

    for i, row in list(missing_lyrics_df.iterrows()):
        artist = row['artists_track'][0]
        title = row['clean_title']

        lyircs = get_lyrics(title, artist)

        if lyircs.strip() == "":
            print("Cannot find lyrics for ", artist, title)

        missing_lyrics_df.loc[i, 'lyrics'] = lyircs

    return missing_lyrics_df
# Out:
# Searching for "taking a chance on love" by Frank Sinatra...
# Done.
# Searching for "something" by Frank Sinatra...
# Done.
# Searching for "concierto de aranjuez" by Frank Sinatra...
# No results found for: 'concierto de aranjuez Frank Sinatra'
# Cannot find lyrics for  Frank Sinatra concierto de aranjuez
# Searching for "bows you are there" by Frank Sinatra...
# Done.
# Searching for "the shadow of your smile" by Frank Sinatra...
# Done.
# Searching for "it was a very good year" by Frank Sinatra...
# Done.
# Searching for "bows my way" by Frank Sinatra...
# Done.
# Searching for "clarke street" by Frank Sinatra...
# Done.
# Searching for "april in paris" by Frank Sinatra...
# Done.
# Searching for "ninna nanna" by Domenico Modugno...
# Done.
# Searching for "i concentrate on you" by Frank Sinatra...
# Done.
# Searching for "april in paris" by Frank Sinatra...
# Done.
# Searching for "it was a very good year" by Frank Sinatra...
# Done.
# Searching for "taking a chance on love" by Frank Sinatra...
# Done.
# Searching for "it was a very good year" by Frank Sinatra...
# Done.
# Searching for "new york bows" by Frank Sinatra...
# Done.
# Searching for "dont cry joe" by Frank Sinatra...
# Done.
# Searching for "the shadow of your smile" by Frank Sinatra...
# Done.
# Searching for "it was a very good year" by Frank Sinatra...
# Done.
# Searching for "april in paris" by Frank Sinatra...
# Done.
# Searching for "a long night" by Frank Sinatra...
# Done.
# Searching for "something" by Frank Sinatra...
# Done.
# Searching for "the future song without words" by Frank Sinatra...
# Done.
# Searching for "something" by The Beatles...
# Done.
# Searching for "oh darling" by The Beatles...
# Done.
# Searching for "something" by The Beatles...
# Done.
# Searching for "golden slumbers carry that weight" by The Beatles...
# Done.
# Searching for "and here we are again" by Rodney Burke...
# Done.
# Searching for "hey paul" by Lee Peters...
# Done.
# Searching for "im talking about you" by The Beatles...
# Done.
# Searching for "a real treat" by Lee Peters...
# Done.
# Searching for "absolutely fab" by Lee Peters...
# Specified song does not contain lyrics. Rejecting.
# Cannot find lyrics for  Lee Peters absolutely fab
# Searching for "lower 5e" by Rodney Burke...
# No results found for: 'lower 5e Rodney Burke'
# Cannot find lyrics for  Rodney Burke lower 5e
# Searching for "the hippy hippy shake" by The Beatles...
# Done.
# Searching for "bumper bundle" by The Beatles...
# Done.
# Searching for "the 49 weeks" by Paul McCartney...
# Done.
# Searching for "sure to fall" by The Beatles...
# Done.
# Searching for "never mind eh" by The Beatles...
# Done.
# Searching for "bye bye" by The Beatles...
# Done.
# Searching for "john" by John Lennon...
# Done.
# Searching for "george" by George Harrison...
# Done.
# Searching for "lift lid again" by Paul McCartney...
# No results found for: 'lift lid again Paul McCartney'
# Cannot find lyrics for  Paul McCartney lift lid again
# Searching for "happy birthday dear saturday club" by The Beatles...
# Done.
# Searching for "now hush hush" by Brian Matthew...
# Done.
# Searching for "brian bathtubes" by John Lennon...
# No results found for: 'brian bathtubes John Lennon'
# Cannot find lyrics for  John Lennon brian bathtubes
# Searching for "if i wasnt in america" by Brian Matthew...
# Done.
# Searching for "something" by The Beatles...
# Done.
# Searching for "too much monkey business" by The Beatles...
# Done.
# Searching for "young blood" by The Beatles...
# Done.
# Searching for "a shot of rhythm and blues" by The Beatles...
# Done.
# Searching for "sure to fall" by The Beatles...
# Done.
# Searching for "thats all right" by The Beatles...
# Done.
# Searching for "what is it george" by The Beatles...
# Done.
# Searching for "to know her is to love her" by The Beatles...
# Done.
# Searching for "ringo yep" by The Beatles...
# Done.
# Searching for "the hippy hippy shake" by The Beatles...
# Done.
# Searching for "something" by The Beatles...
# Done.
# Searching for "oh darling" by The Beatles...
# Done.
# Searching for "pepperland" by George Martin...
# Done.
# Searching for "sea of time" by George Martin...
# Done.
# Searching for "sea of holes" by George Martin...
# Done.
# Searching for "sea of monsters" by George Martin...
# Done.
# Searching for "march of the meanies" by George Martin...
# Done.
# Searching for "pepperland laid waste" by George Martin...
# Done.
# Searching for "yellow submarine in pepperland" by George Martin...
# Done.
# Searching for "good night" by The Beatles...
# Done.
# Searching for "flying" by The Beatles...
# Done.
# Searching for "drive my car" by The Beatles...
# Done.
# Searching for "bad guy" by Eminem...
# Done.
# Searching for "so much better" by Eminem...
# Done.
# Searching for "rap god" by Eminem...
# Done.
# Searching for "bad guy" by Eminem...
# Done.
# Searching for "so much better" by Eminem...
# Done.
# Searching for "rap god" by Eminem...
# Done.
# Searching for "bad guy" by Eminem...
# Done.
# Searching for "so much better" by Eminem...
# Done.
# Searching for "rap god" by Eminem...
# Done.
# Searching for "bad guy" by Eminem...
# Done.
# Searching for "so much better" by Eminem...
# Done.
# Searching for "rap god" by Eminem...
# Done.
# Searching for "bad guy" by Eminem...
# Done.
# Searching for "so much better" by Eminem...
# Done.
# Searching for "rap god" by Eminem...
# Done.
# Searching for "bad guy" by Eminem...
# Done.
# Searching for "so much better" by Eminem...
# Done.
# Searching for "rap god" by Eminem...
# Done.
# Searching for "bad guy" by Eminem...
# Done.
# Searching for "so much better" by Eminem...
# Done.
# Searching for "rap god" by Eminem...
# Done.
# Searching for "bad guy" by Eminem...
# Done.
# Searching for "so much better" by Eminem...
# Done.
# Searching for "rap god" by Eminem...
# Done.
# Searching for "on fire" by Eminem...
# Done.
# Searching for "on fire" by Eminem...
# Done.
# Searching for "on fire" by Eminem...
# Done.
# Searching for "on fire" by Eminem...
# Done.
#                                           name_track  \
# 0          Taking a Chance On Love - 2007 - Remaster
# 1  Something - Live At The Budokan Hall, Tokyo / ...
# 2  Concierto de Aranjuez - Live At The Budokan Ha...
# 3  Bows: You Are There - Live At The Budokan Hall...
# 4  The Shadow Of Your Smile - Live At The Sands H...
#
#                                     name_album  artists_album  \
# 0                   I've Got You Under My Skin  Frank Sinatra
# 1  Sinatra In Japan (Live At The Budokan/1985)  Frank Sinatra
# 2  Sinatra In Japan (Live At The Budokan/1985)  Frank Sinatra
# 3  Sinatra In Japan (Live At The Budokan/1985)  Frank Sinatra
# 4                           Standing Room Only  Frank Sinatra
#
#                 clean_title    artists_track  \
# 0   taking a chance on love  [Frank Sinatra]
# 1                 something  [Frank Sinatra]
# 2     concierto de aranjuez  [Frank Sinatra]
# 3        bows you are there  [Frank Sinatra]
# 4  the shadow of your smile  [Frank Sinatra]
#
#                                               lyrics
# 0  Writer(s): Latouche/Fetter/Duke\n\nHere I go a...
# 1  Something in the way she moves, attracts me li...
# 2
# 3                                     [Instrumental]
# 4  The shadow of your smile\nWhen you have gone\n...

# %%
missing_lyrics_df.to_csv("../data/additional_lyrics.csv", index=False)

# %% [markdown]
# ### Import and insert additional lyrics

# %%
additional_lyrics_df = pd.read_csv("../data/additional_lyrics.csv")

full_df_additional = full_df.merge(additional_lyrics_df[['name_track', 'name_album', 'lyrics']], on=['name_track', 'name_album'])
full_df_additional.fillna("", inplace=True)

full_df_additional['lyrics'] = full_df_additional['lyrics_x'] + full_df_additional['lyrics_y']
full_df_additional.drop(columns=['lyrics_x', 'lyrics_y'], inplace=True)


full_df_additional

full_df.to_csv('../data/spot_lyr_df_jon.csv')

# %%
literal_eval(full_df.iloc[0].artists_track)
# Out:
# ['Frank Sinatra']

# %%
full_df.featuring = full_df.apply(lambda row: len(literal_eval(row['artists_track'])) > 1 or (not row['artists_album'] in literal_eval(row['artists_track'])), axis=1)
full_df = full_df.rename(columns={'artists_album': 'artist'})

# %%
full_df[full_df.featuring == True]
# Out:
#                                    name_track  duration_ms  explicit  \
# 8                             L.A. Is My Lady       195160     False
# 9          How Do You Keep The Music Playing?       235200     False
# 115           Whatever Happened To Christmas?       186360     False
# 116              The Twelve Days Of Christmas       272013     False
# 117     The Bells Of Christmas (Greensleeves)       221320     False
# ...                                       ...          ...       ...
# 1679                           Talk That Talk       209600      True
# 1689                            We Found Love       215226     False
# 1690  Talk That Talk - Album Version (Edited)       209600     False
# 1700                            We Found Love       215226     False
# 1701                           Talk That Talk       209600      True
#
#                                           artists_track  \
# 8                     ['Frank Sinatra', 'Quincy Jones']
# 9                     ['Frank Sinatra', 'Quincy Jones']
# 115        ['Frank Sinatra', 'The Jimmy Joyce Singers']
# 116   ['Frank Sinatra', 'Frank Sinatra Jr.', 'Nancy ...
# 117   ['Frank Sinatra', 'Frank Sinatra Jr.', 'Nancy ...
# ...                                                 ...
# 1679                               ['Rihanna', 'JAY-Z']
# 1689                       ['Rihanna', 'Calvin Harris']
# 1690                               ['Rihanna', 'JAY-Z']
# 1700                       ['Rihanna', 'Calvin Harris']
# 1701                               ['Rihanna', 'JAY-Z']
#
#                                       artists_track_uri  featuring  \
# 8     ['spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0', 'spo...       True
# 9     ['spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0', 'spo...       True
# 115   ['spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0', 'spo...       True
# 116   ['spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0', 'spo...       True
# 117   ['spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0', 'spo...       True
# ...                                                 ...        ...
# 1679  ['spotify:artist:5pKCCKE2ajJHZ9KAiaK11H', 'spo...       True
# 1689  ['spotify:artist:5pKCCKE2ajJHZ9KAiaK11H', 'spo...       True
# 1690  ['spotify:artist:5pKCCKE2ajJHZ9KAiaK11H', 'spo...       True
# 1700  ['spotify:artist:5pKCCKE2ajJHZ9KAiaK11H', 'spo...       True
# 1701  ['spotify:artist:5pKCCKE2ajJHZ9KAiaK11H', 'spo...       True
#
#       track_number  disc_number                            name_album  \
# 8                9            1  Sinatra Sings Alan & Marilyn Bergman
# 9               10            1  Sinatra Sings Alan & Marilyn Bergman
# 115             14            1                    Ultimate Christmas
# 116             15            1                    Ultimate Christmas
# 117             16            1                    Ultimate Christmas
# ...            ...          ...                                   ...
# 1679             4            1                        Talk That Talk
# 1689             3            1                        Talk That Talk
# 1690             4            1                        Talk That Talk
# 1700             3            1      Talk That Talk (Deluxe Explicit)
# 1701             4            1      Talk That Talk (Deluxe Explicit)
#
#              artist  ...  speechiness acousticness instrumentalness  liveness  \
# 8     Frank Sinatra  ...       0.0590       0.6920         0.000000    0.1190
# 9     Frank Sinatra  ...       0.0332       0.9500         0.000193    0.0692
# 115   Frank Sinatra  ...       0.0348       0.8030         0.003200    0.2620
# 116   Frank Sinatra  ...       0.0369       0.9270         0.000000    0.1210
# 117   Frank Sinatra  ...       0.0309       0.8630         0.000000    0.3190
# ...             ...  ...          ...          ...              ...       ...
# 1679        Rihanna  ...       0.0444       0.0371         0.000031    0.2360
# 1689        Rihanna  ...       0.0383       0.0250         0.001380    0.1080
# 1690        Rihanna  ...       0.0544       0.0332         0.000013    0.2110
# 1700        Rihanna  ...       0.0383       0.0250         0.001380    0.1080
# 1701        Rihanna  ...       0.0444       0.0371         0.000031    0.2360
#
#       valence    tempo  time_signature                        clean_title  \
# 8       0.549  112.812               4                      la_is_my_lady
# 9       0.267   76.091               4  how_do_you_keep_the_music_playing
# 115     0.253   67.303               3     whatever_happened_to_christmas
# 116     0.479  123.898               1       the_twelve_days_of_christmas
# 117     0.205   85.488               4             the_bells_of_christmas
# ...       ...      ...             ...                                ...
# 1679    0.466   83.999               4                     talk_that_talk
# 1689    0.600  127.986               4                      we_found_love
# 1690    0.375  168.055               4                     talk_that_talk
# 1700    0.600  127.986               4                      we_found_love
# 1701    0.466   83.999               4                     talk_that_talk
#
#                                                  lyrics  lyrics_state
# 8     The music she moves to, is music that makes me...      complete
# 9     (Lorrie)\nHow do you keep the music playing, h...      complete
# 115   Whatever happened to Christmas? It's gone and ...      complete
# 116   (not Frank's version, this is the traditional)...      complete
# 117   The bells, the bells\nRinging everywhere for t...      complete
# ...                                                 ...           ...
# 1679  Talk that talk to me, yeah\nTalk that talk to ...      complete
# 1689  Yellow diamonds in the light\nAnd we're standi...      complete
# 1690  Talk that talk to me, yeah\nTalk that talk to ...      complete
# 1700  Yellow diamonds in the light\nAnd we're standi...      complete
# 1701  Talk that talk to me, yeah\nTalk that talk to ...      complete
#
# [289 rows x 28 columns]
